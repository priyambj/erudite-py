# %%
from __future__ import print_function, division
from graph_tool.all import *
# %pylab inline

g = Graph()
v1 = g.add_vertex()
l = g.new_vertex_property('string')
l[v1] = u'bla\nbla'
graph_draw(g, vertex_text=l, inline=True)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['show_config']
# `%matplotlib` prevents importing * from pylab and numpy
# <PropertyMap object with key type 'Vertex' and value type 'vector<double>', for Graph 0x7f5ae173cc50, at 0x7f5ae16d4c50>
